# %% [markdown]
# <a href="https://colab.research.google.com/github/Sibonile7/Elderly-Fall-Detection-using-AI-SisFall-Dataset-/blob/main/Huggy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get update -y
# !apt-get install -y python3.10 python3.10-venv python3.10-distutils
# !python3.10 -m venv /content/py310
# Out:
# Hit:1 https://cli.github.com/packages stable InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Get:8 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:12 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,819 kB]
# Get:13 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,402 kB]
# Fetched 12.2 MB in 2s (5,137 kB/s)
# ...

# %%
# !git clone --depth 1 https://github.com/Unity-Technologies/ml-agents.git
# %cd /content/ml-agents
# Out:
# fatal: destination path 'ml-agents' already exists and is not an empty directory.
# /content/ml-agents

# %%
# ✅ Re-check versions (mlagents has no __version__, use importlib.metadata)
script = """
from importlib.metadata import version, PackageNotFoundError
import mlagents_envs

def v(name):
    try:
        return version(name)
    except PackageNotFoundError:
        return "not installed"

print("mlagents (dist):", v("mlagents"))
print("mlagents_envs (pkg):", mlagents_envs.__version__)
print("mlagents_envs (dist):", v("mlagents-envs"))
"""
with open("/tmp/check_mlagents.py", "w") as f:
    f.write(script)

# Run with the Python 3.10 venv
# !bash -lc "/content/py310/bin/python /tmp/check_mlagents.py"

# Confirm CLI exists
# !bash -lc "/content/py310/bin/mlagents-learn --help | head -n 8"
# Out:
# mlagents (dist): 1.2.0.dev0
# mlagents_envs (pkg): 1.2.0.dev0
# mlagents_envs (dist): 1.2.0.dev0
# /content/ml-agents/ml-agents/mlagents/torch_utils/torch.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# usage: mlagents-learn [-h] [--env ENV_PATH] [--resume] [--deterministic]
#                       [--force] [--run-id RUN_ID] [--initialize-from RUN_ID]
#                       [--seed SEED] [--inference] [--base-port BASE_PORT]
#                       [--num-envs NUM_ENVS] [--num-areas NUM_AREAS] [--debug]
#                       [--env-args ...]
#                       [--max-lifetime-restarts MAX_LIFETIME_RESTARTS]
#                       [--restarts-rate-limit-n RESTARTS_RATE_LIMIT_N]
# ...

# %%
# !mkdir -p /content/ml-agents/trained-envs-executables/linux
# !wget -q "https://github.com/huggingface/Huggy/raw/main/Huggy.zip" -O /content/ml-agents/trained-envs-executables/linux/Huggy.zip
# !unzip -q -o /content/ml-agents/trained-envs-executables/linux/Huggy.zip -d /content/ml-agents/trained-envs-executables/linux/
# !chmod +x /content/ml-agents/trained-envs-executables/linux/Huggy/Huggy.x86_64

# %%
# !bash -lc '/content/py310/bin/mlagents-learn /content/ml-agents/config/ppo/Huggy.yaml \
  --env=/content/ml-agents/trained-envs-executables/linux/Huggy/Huggy.x86_64 \
  --run-id=Huggy --no-graphics --resume'
# Out:
# /content/ml-agents/ml-agents/mlagents/torch_utils/torch.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
#
#             ┐  ╖
#         ╓╖╬│╡  ││╬╖╖
#     ╓╖╬│││││┘  ╬│││││╬╖
#  ╖╬│││││╬╜        ╙╬│││││╖╖                               ╗╗╗
#  ╬╬╬╬╖││╦╖        ╖╬││╗╣╣╣╬      ╟╣╣╬    ╟╣╣╣             ╜╜╜  ╟╣╣
#  ╬╬╬╬╬╬╬╬╖│╬╖╖╓╬╪│╓╣╣╣╣╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╒╣╣╖╗╣╣╣╗   ╣╣╣ ╣╣╣╣╣╣ ╟╣╣╖   ╣╣╣
#  ╬╬╬╬┐  ╙╬╬╬╬│╓╣╣╣╝╜  ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╣╙ ╙╣╣╣  ╣╣╣ ╙╟╣╣╜╙  ╫╣╣  ╟╣╣
#  ╬╬╬╬┐     ╙╬╬╣╣      ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣     ╣╣╣┌╣╣╜
#  ╬╬╬╜       ╬╬╣╣      ╙╝╣╣╬      ╙╣╣╣╗╖╓╗╣╣╣╜ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣╦╓    ╣╣╣╣╣
#  ╙   ╓╦╖    ╬╬╣╣   ╓╗╗╖            ╙╝╣╣╣╣╝╜   ╘╝╝╜   ╝╝╝  ╝╝╝   ╙╣╣╣    ╟╣╣╣
# ...

# %%
from huggingface_hub import notebook_login

notebook_login()

# %%
# !bash -lc '/content/py310/bin/mlagents-push-to-hf \
  --run-id="HuggyTraining" \
  --local-dir="/content/ml-agents/results/Huggy" \
  --repo-id="Sibonile/ppo-Huggy" \
  --commit-message="Huggy"'
# Out:
# [INFO] This function will create a model card and upload your HuggyTraining into HuggingFace Hub. This is a work in progress: If you encounter a bug, please send open an issue
# [INFO] Pushing repo HuggyTraining to the Hugging Face Hub
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#
#   .../results/Huggy/Huggy.onnx: 100% 2.27M/2.27M [00:00<?, ?B/s]
#
#
#   .../Huggy/Huggy-1199963.onnx: 100% 2.27M/2.27M [00:00<?, ?B/s]
#
#
#
#   ...y/Huggy/Huggy-399983.onnx: 100% 2.27M/2.27M [00:00<?, ?B/s]
#
#
#
#
#   .../Huggy/Huggy-1399888.onnx: 100% 2.27M/2.27M [00:00<?, ?B/s]
#
#
#
#
#
#   ...y/Huggy/Huggy-599901.onnx: 100% 2.27M/2.27M [00:00<?, ?B/s]
#
#
#
#
#
#
#   ...gy/Huggy/Huggy-1199963.pt:  61% 8.28M/13.5M [00:00<?, ?B/s]
#
#
#
#
#
#
#
#   ...ggy/Huggy/Huggy-399983.pt:  62% 8.37M/13.5M [00:00<?, ?B/s]
#
#
#
#
#
#
#
#
#   ...gy/Huggy/Huggy-2000024.pt:  62% 8.39M/13.5M [00:00<?, ?B/s]
#
#
#
#
#
#
#
#
#
# ...
